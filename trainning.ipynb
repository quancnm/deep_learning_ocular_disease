# %%
# !pip install -q efficientnet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 KB 972.9 kB/s eta 0:00:00

# %% [markdown]
# Mount google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
! pip install kaggle
! mkdir ~/.kaggle
! cp '/content/drive/MyDrive/Colab Notebooks/kaggle.json' ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: kaggle in /usr/local/lib/python3.8/dist-packages (1.5.12)
# Requirement already satisfied: certifi in /usr/local/lib/python3.8/dist-packages (from kaggle) (2022.12.7)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from kaggle) (2.25.1)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.8/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.8/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from kaggle) (4.64.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.8/dist-packages (from kaggle) (7.0.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.8/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.8/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->kaggle) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->kaggle) (4.0.0)
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
# !kaggle datasets download -d andrewmvd/ocular-disease-recognition-odir5k
# Out:
# Downloading ocular-disease-recognition-odir5k.zip to /content
#  95% 1.54G/1.62G [00:07<00:00, 208MB/s]
# User cancelled operation

# %%
# !unzip /content/ocular-disease-recognition-odir5k.zip
# Out:
# Archive:  /content/ocular-disease-recognition-odir5k.zip
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of /content/ocular-disease-recognition-odir5k.zip or
#         /content/ocular-disease-recognition-odir5k.zip.zip, and cannot find /content/ocular-disease-recognition-odir5k.zip.ZIP, period.

# %%
# !pip install tensorflow-addons==0.16.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow-addons==0.16.1
#   Downloading tensorflow_addons-0.16.1-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 35.7 MB/s eta 0:00:00
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.8/dist-packages (from tensorflow-addons==0.16.1) (2.7.1)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.16.1

# %% [markdown]
# Import libraries

# %%
import os, glob, cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras import backend as K
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import get_custom_objects
import efficientnet.tfkeras as efn
from tqdm import tqdm
import random
import tensorflow_addons as tfa
# Out:
# /usr/local/lib/python3.8/dist-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.6.0 and strictly below 2.9.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.9.2 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %% [markdown]
# Configuration and image root

# %%
SEED = 42
EPOCHS = 100
BATCH_SIZE = 24
IMG_HEIGHT = 256
IMG_WIDTH = 256

IMG_ROOT = '/content/drive/MyDrive/dataset/'
IMG_DIR = [ 
           IMG_ROOT+'2_cataract', 
           IMG_ROOT+'2_glaucoma' 
           ]
# ocular-disease-recognition dataset
OCU_IMG_ROOT = '/content/drive/MyDrive/ODIR-5K/Training Images/'

ocu_df = pd.read_excel('/content/drive/MyDrive/ODIR-5K/data.xlsx')

# %% [markdown]
# Generate seed

# %%
def seed_everything(seed):
    np.random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    tf.random.set_seed(seed)

seed_everything(SEED)

# %% [markdown]
# Preprocess image data

# %%
sec1_df = pd.DataFrame(0, 
                  columns=['paths', 
                           'label'],
                  index=range(510))

filepath_cat = glob.glob(IMG_ROOT+'2_cataract' + '*/*')


for i, filepath in enumerate(filepath_cat):
    filepath = os.path.split(filepath)
    sec1_df.iloc[i, 0] = filepath[0]+'/'+filepath[1]
    sec1_df.iloc[i, 1] = 2
sec2_df = pd.DataFrame(0, 
                  columns=['paths', 
                           'label'],
                  index=range(510))
filepath_glau = glob.glob(IMG_ROOT+'2_glaucoma' + '*/*')    
for i, filepath in enumerate(filepath_glau):
    filepath = os.path.split(filepath)
    sec2_df.iloc[i, 0] = filepath[0]+'/'+filepath[1]
    sec2_df.iloc[i, 1] = 3



sec_df = pd.concat([sec1_df,sec2_df])
sec_df= sec_df[((sec_df['label'] != 0) )]
sec_df
# Out:
#                                                  paths  label
# 0    /content/drive/MyDrive/dataset/2_cataract/Flip...      2
# 1    /content/drive/MyDrive/dataset/2_cataract/Flip...      2
# 2    /content/drive/MyDrive/dataset/2_cataract/Flip...      2
# 3    /content/drive/MyDrive/dataset/2_cataract/Flip...      2
# 4    /content/drive/MyDrive/dataset/2_cataract/Flip...      2
# ..                                                 ...    ...
# 426  /content/drive/MyDrive/dataset/2_glaucoma/Glau...      3
# 427  /content/drive/MyDrive/dataset/2_glaucoma/Glau...      3
# 428  /content/drive/MyDrive/dataset/2_glaucoma/Glau...      3
# 429  /content/drive/MyDrive/dataset/2_glaucoma/Glau...      3
# 430  /content/drive/MyDrive/dataset/2_glaucoma/Glau...      3
#
# [867 rows x 2 columns]

# %%
ocu_df.head()
# Out:
#    ID  Patient Age Patient Sex Left-Fundus Right-Fundus  \
# 0   0           69      Female  0_left.jpg  0_right.jpg
# 1   1           57        Male  1_left.jpg  1_right.jpg
# 2   2           42        Male  2_left.jpg  2_right.jpg
# 3   3           66        Male  3_left.jpg  3_right.jpg
# 4   4           53        Male  4_left.jpg  4_right.jpg
#
#                             Left-Diagnostic Keywords  \
# 0                                           cataract
# 1                                      normal fundus
# 2  laser spot，moderate non proliferative retinopathy
# 3                                      normal fundus
# 4                        macular epiretinal membrane
#
#                 Right-Diagnostic Keywords  N  D  G  C  A  H  M  O
# 0                           normal fundus  0  0  0  1  0  0  0  0
# 1                           normal fundus  1  0  0  0  0  0  0  0
# 2  moderate non proliferative retinopathy  0  1  0  0  0  0  0  1
# 3         branch retinal artery occlusion  0  0  0  0  0  0  0  1
# 4       mild nonproliferative retinopathy  0  1  0  0  0  0  0  1

# %% [markdown]
# Labeling data

# %%
def labeling(text):
    if 'normal fundus' in text:
        return 1
    if 'cataract' in text:
        
          return 2
      
    if 'glaucoma' in text:
       
          return 3
        
    #if 'proliferative retinopathy' in text or 'diabetic' in text:
        #return 4
    else:
        return 0
ocu_df['left_eye_disease'] = ocu_df['Left-Diagnostic Keywords']\
                                 .apply(lambda x: labeling(x))
ocu_df['right_eye_disease'] = ocu_df['Right-Diagnostic Keywords']\
                                 .apply(lambda x: labeling(x))

# %% [markdown]
# Preprocess data

# %%
le_df = ocu_df.loc[:, ['Left-Fundus', 'left_eye_disease']]\
        .rename(columns={'left_eye_disease':'label'})
le_df['paths'] = OCU_IMG_ROOT + le_df['Left-Fundus']
le_df = le_df.drop('Left-Fundus', axis=1)

le_df= le_df[((le_df['label'] != 0) )]
le_df = le_df.reset_index(drop=True)


re_df = ocu_df.loc[:, ['Right-Fundus', 'right_eye_disease']]\
        .rename(columns={'right_eye_disease':'label'})
re_df['paths'] = OCU_IMG_ROOT + re_df['Right-Fundus']
re_df = re_df.drop('Right-Fundus', axis=1)

re_df= re_df[((re_df['label'] != 0) )]
re_df = re_df.reset_index(drop=True)

# %%
ocu_df = pd.concat([le_df, re_df, sec_df])
ocu_df
# Out:
#      label                                              paths
# 0        2  /content/drive/MyDrive/ODIR-5K/Training Images...
# 1        1  /content/drive/MyDrive/ODIR-5K/Training Images...
# 2        1  /content/drive/MyDrive/ODIR-5K/Training Images...
# 3        1  /content/drive/MyDrive/ODIR-5K/Training Images...
# 4        1  /content/drive/MyDrive/ODIR-5K/Training Images...
# ..     ...                                                ...
# 426      3  /content/drive/MyDrive/dataset/2_glaucoma/Glau...
# 427      3  /content/drive/MyDrive/dataset/2_glaucoma/Glau...
# 428      3  /content/drive/MyDrive/dataset/2_glaucoma/Glau...
# 429      3  /content/drive/MyDrive/dataset/2_glaucoma/Glau...
# 430      3  /content/drive/MyDrive/dataset/2_glaucoma/Glau...
#
# [4602 rows x 2 columns]

# %% [markdown]
# Observe bias in dataset

# %%
print(ocu_df['label'].value_counts())
# Out:
# 1    3098
# 3     755
# 2     749
# Name: label, dtype: int64

# %% [markdown]
# Down sample to make dataset even

# %%
def downsample(df):
    df = pd.concat([
        df.query('label==3').sample(ocu_df['label'].value_counts()[2], 
                                       random_state=SEED),
        df.query('label==2').sample(ocu_df['label'].value_counts()[2], 
                                       random_state=SEED),
        df.query('label==1').sample(ocu_df['label'].value_counts()[2], 
                                       random_state=SEED)
        #df.query('label==4').sample(ocu_df['label'].value_counts()[2], 
                                       #random_state=SEED)
    ], ignore_index=True)
    return df


ocu_df = downsample(ocu_df)

ocu_df = ocu_df.sample(frac=1).reset_index(drop=True)
ocu_df = ocu_df.sample(frac=1).reset_index(drop=True)
print('Number of eye images')
print(ocu_df['label'].value_counts())
# Out:
# Number of eye images
# 2    749
# 3    749
# 1    749
# Name: label, dtype: int64

# %% [markdown]
# Split dataset

# %%
#train_df, test_df = train_test_split(ocu_df, 
                                     #test_size=0.15, 
                                     #random_state=SEED, 
                                     #stratify=ocu_df['label'])

train_df, val_df = train_test_split(ocu_df,
                                    test_size=0.25,
                                    random_state=SEED,
                                    stratify=ocu_df['label'])

# %%
df = pd.get_dummies(ocu_df['label'])
df
# Out:
#       1  2  3
# 0     0  1  0
# 1     0  1  0
# 2     0  1  0
# 3     0  0  1
# 4     0  0  1
# ...  .. .. ..
# 2242  0  1  0
# 2243  0  0  1
# 2244  0  1  0
# 2245  0  1  0
# 2246  1  0  0
#
# [2247 rows x 3 columns]

# %% [markdown]
# Preprocess image and create dataset

# %%
def create_datasets(df, img_width, img_height):
    imgs = []
    target_shape=(img_width, img_height)
    for path in tqdm(df['paths']):
        image = cv2.imread(path, cv2.IMREAD_COLOR) # load from the directory
        non_0_rows = np.array([row_idx for row_idx, row in enumerate(image) if np.count_nonzero(row)!=0])
        non_0_cols = np.array([col_idx for col_idx, col in enumerate(image.transpose(1,0,2)) if np.count_nonzero(col)!=0])
        image = image[non_0_rows.min():non_0_rows.max()+1, non_0_cols.min():non_0_cols.max()+1, :] 
        image = cv2.resize(image, target_shape)
        imgs.append(image)
        
    imgs = np.array(imgs, dtype='float32')
    df = pd.get_dummies(df['label'])
    return imgs, df


train_imgs, train_df = create_datasets(train_df, IMG_WIDTH, IMG_HEIGHT)
val_imgs, val_df = create_datasets(val_df, IMG_WIDTH, IMG_HEIGHT)
#test_imgs, test_df = create_datasets(test_df, IMG_WIDTH, IMG_HEIGHT)

train_imgs = train_imgs / 255.0
val_imgs = val_imgs / 255.0
#test_imgs = test_imgs / 255.0
# Out:
# 100%|██████████| 1685/1685 [21:28<00:00,  1.31it/s]
# 100%|██████████| 562/562 [07:12<00:00,  1.30it/s]

# %% [markdown]
# Generate custome activation

# %%
class Mish(tf.keras.layers.Layer):

    def __init__(self, **kwargs):
        super(Mish, self).__init__(**kwargs)
        self.supports_masking = True

    def call(self, inputs):
        return inputs * K.tanh(K.softplus(inputs))

    def get_config(self):
        base_config = super(Mish, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

    def compute_output_shape(self, input_shape):
        return input_shape
def mish(x):
    return tf.keras.layers.Lambda(lambda x: x*K.tanh(K.softplus(x)))(x)
 
get_custom_objects().update({'mish': Activation(mish)})

# %% [markdown]
# Buil model

# %%
input_shape = (IMG_HEIGHT, IMG_WIDTH, 3)

model = Sequential()
model.add(Conv2D(16, kernel_size=3, padding='same', 
                 input_shape=input_shape, activation='mish'))
model.add(Conv2D(16, kernel_size=3, padding='same', activation='mish'))
model.add(BatchNormalization())
model.add(MaxPool2D(3))
model.add(Dropout(0.3))
model.add(Conv2D(16, kernel_size=3, padding='same', activation='mish'))
model.add(Conv2D(16, kernel_size=3, padding='same', activation='mish'))
model.add(BatchNormalization())
model.add(MaxPool2D(3))
model.add(Dropout(0.3))

model.add(Flatten())
model.add(Dense(1024, activation='relu'))
model.add(Dense(512, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(3, activation='softmax'))
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.000003), loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.01), metrics=['accuracy'])



model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 256, 256, 16)      448
#
#  conv2d_5 (Conv2D)           (None, 256, 256, 16)      2320
#
#  batch_normalization_2 (Batc  (None, 256, 256, 16)     64
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 85, 85, 16)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 85, 85, 16)        0
#
#  conv2d_6 (Conv2D)           (None, 85, 85, 16)        2320
#
#  conv2d_7 (Conv2D)           (None, 85, 85, 16)        2320
#
#  batch_normalization_3 (Batc  (None, 85, 85, 16)       64
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 28, 28, 16)       0
#  2D)
#
#  dropout_3 (Dropout)         (None, 28, 28, 16)        0
#
#  flatten_1 (Flatten)         (None, 12544)             0
#
#  dense_12 (Dense)            (None, 1024)              12846080
#
#  dense_13 (Dense)            (None, 512)               524800
#
#  dense_14 (Dense)            (None, 256)               131328
#
#  dense_15 (Dense)            (None, 128)               32896
#
#  dense_16 (Dense)            (None, 64)                8256
#
#  dense_17 (Dense)            (None, 32)                2080
#
#  dense_18 (Dense)            (None, 16)                528
#
#  dense_19 (Dense)            (None, 8)                 136
#
#  dense_20 (Dense)            (None, 3)                 27
#
# =================================================================
# Total params: 13,553,667
# Trainable params: 13,553,603
# Non-trainable params: 64
# _________________________________________________________________

# %% [markdown]
# Data augumentation: flip, reflect; Early stop and Reduce learning rate

# %%
generator = ImageDataGenerator(horizontal_flip=True, 
                               height_shift_range=0.1,
                               fill_mode='reflect') 



es_callback = tf.keras.callbacks.EarlyStopping(patience=90, 
                                               verbose=1, 
                                               restore_best_weights=True)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(factor=0.1, patience=80, verbose=1)

# %% [markdown]
# training

# %%
history = model.fit(train_imgs, train_df,batch_size=32,epochs=200,
                    steps_per_epoch=len(train_imgs)/32,
                    callbacks=[es_callback, reduce_lr],
                    validation_data=(val_imgs, val_df))


pd.DataFrame(history.history)[['accuracy', 'val_accuracy']].plot()
pd.DataFrame(history.history)[['loss', 'val_loss']].plot()
plt.show()
# Out:
# Epoch 1/200
# 52/52 [==============================] - 34s 464ms/step - loss: 1.0972 - accuracy: 0.3513 - val_loss: 1.0963 - val_accuracy: 0.3327 - lr: 3.0000e-06
# Epoch 2/200
# 52/52 [==============================] - 21s 406ms/step - loss: 1.0948 - accuracy: 0.3418 - val_loss: 1.0960 - val_accuracy: 0.3612 - lr: 3.0000e-06
# Epoch 3/200
# 52/52 [==============================] - 21s 406ms/step - loss: 1.0902 - accuracy: 0.3685 - val_loss: 1.0983 - val_accuracy: 0.3630 - lr: 3.0000e-06
# Epoch 4/200
# 52/52 [==============================] - 21s 402ms/step - loss: 1.0871 - accuracy: 0.4047 - val_loss: 1.1003 - val_accuracy: 0.3541 - lr: 3.0000e-06
# Epoch 5/200
# 52/52 [==============================] - 21s 404ms/step - loss: 1.0837 - accuracy: 0.4089 - val_loss: 1.0967 - val_accuracy: 0.3505 - lr: 3.0000e-06
# Epoch 6/200
# 52/52 [==============================] - 21s 408ms/step - loss: 1.0802 - accuracy: 0.4332 - val_loss: 1.0908 - val_accuracy: 0.3594 - lr: 3.0000e-06
# Epoch 7/200
# 52/52 [==============================] - 21s 404ms/step - loss: 1.0768 - accuracy: 0.4481 - val_loss: 1.0879 - val_accuracy: 0.3523 - lr: 3.0000e-06
# Epoch 8/200
# 52/52 [==============================] - 21s 407ms/step - loss: 1.0729 - accuracy: 0.4475 - val_loss: 1.0804 - val_accuracy: 0.3754 - lr: 3.0000e-06
# Epoch 9/200
# 52/52 [==============================] - 21s 400ms/step - loss: 1.0684 - accuracy: 0.4611 - val_loss: 1.0711 - val_accuracy: 0.4057 - lr: 3.0000e-06
# Epoch 10/200
# 52/52 [==============================] - 21s 402ms/step - loss: 1.0657 - accuracy: 0.4564 - val_loss: 1.0641 - val_accuracy: 0.4324 - lr: 3.0000e-06
# Epoch 11/200
# 52/52 [==============================] - 21s 401ms/step - loss: 1.0600 - accuracy: 0.4754 - val_loss: 1.0586 - val_accuracy: 0.4520 - lr: 3.0000e-06
# Epoch 12/200
# 52/52 [==============================] - 21s 406ms/step - loss: 1.0556 - accuracy: 0.4884 - val_loss: 1.0547 - val_accuracy: 0.4573 - lr: 3.0000e-06
# Epoch 13/200
# 52/52 [==============================] - 22s 427ms/step - loss: 1.0514 - accuracy: 0.4789 - val_loss: 1.0507 - val_accuracy: 0.4662 - lr: 3.0000e-06
# Epoch 14/200
# 52/52 [==============================] - 21s 405ms/step - loss: 1.0453 - accuracy: 0.5116 - val_loss: 1.0461 - val_accuracy: 0.4662 - lr: 3.0000e-06
# Epoch 15/200
# 52/52 [==============================] - 21s 408ms/step - loss: 1.0418 - accuracy: 0.4991 - val_loss: 1.0418 - val_accuracy: 0.4804 - lr: 3.0000e-06
# Epoch 16/200
# 52/52 [==============================] - 21s 408ms/step - loss: 1.0367 - accuracy: 0.4926 - val_loss: 1.0374 - val_accuracy: 0.4786 - lr: 3.0000e-06
# Epoch 17/200
# 52/52 [==============================] - 21s 407ms/step - loss: 1.0322 - accuracy: 0.4955 - val_loss: 1.0326 - val_accuracy: 0.4822 - lr: 3.0000e-06
# Epoch 18/200
# 52/52 [==============================] - 21s 406ms/step - loss: 1.0257 - accuracy: 0.5045 - val_loss: 1.0286 - val_accuracy: 0.4875 - lr: 3.0000e-06
# Epoch 19/200
# 52/52 [==============================] - 21s 407ms/step - loss: 1.0211 - accuracy: 0.5163 - val_loss: 1.0239 - val_accuracy: 0.4911 - lr: 3.0000e-06
# Epoch 20/200
# 52/52 [==============================] - 23s 429ms/step - loss: 1.0168 - accuracy: 0.5169 - val_loss: 1.0197 - val_accuracy: 0.4858 - lr: 3.0000e-06
# Epoch 21/200
# 52/52 [==============================] - 21s 408ms/step - loss: 1.0117 - accuracy: 0.5050 - val_loss: 1.0148 - val_accuracy: 0.4822 - lr: 3.0000e-06
# Epoch 22/200
# 52/52 [==============================] - 21s 407ms/step - loss: 1.0050 - accuracy: 0.5157 - val_loss: 1.0102 - val_accuracy: 0.4840 - lr: 3.0000e-06
# Epoch 23/200
# 52/52 [==============================] - 23s 429ms/step - loss: 0.9996 - accuracy: 0.5139 - val_loss: 1.0060 - val_accuracy: 0.4858 - lr: 3.0000e-06
# Epoch 24/200
# 52/52 [==============================] - 21s 405ms/step - loss: 0.9964 - accuracy: 0.5045 - val_loss: 1.0022 - val_accuracy: 0.4893 - lr: 3.0000e-06
# Epoch 25/200
# 52/52 [==============================] - 21s 407ms/step - loss: 0.9901 - accuracy: 0.5294 - val_loss: 0.9978 - val_accuracy: 0.4875 - lr: 3.0000e-06
# Epoch 26/200
# 52/52 [==============================] - 21s 406ms/step - loss: 0.9884 - accuracy: 0.5264 - val_loss: 0.9933 - val_accuracy: 0.4964 - lr: 3.0000e-06
# Epoch 27/200
# 52/52 [==============================] - 21s 404ms/step - loss: 0.9779 - accuracy: 0.5240 - val_loss: 0.9890 - val_accuracy: 0.4929 - lr: 3.0000e-06
# Epoch 28/200
# 52/52 [==============================] - 21s 405ms/step - loss: 0.9721 - accuracy: 0.5288 - val_loss: 0.9846 - val_accuracy: 0.4964 - lr: 3.0000e-06
# Epoch 29/200
# 52/52 [==============================] - 21s 409ms/step - loss: 0.9669 - accuracy: 0.5294 - val_loss: 0.9811 - val_accuracy: 0.5000 - lr: 3.0000e-06
# Epoch 30/200
# 52/52 [==============================] - 21s 407ms/step - loss: 0.9655 - accuracy: 0.5211 - val_loss: 0.9776 - val_accuracy: 0.4982 - lr: 3.0000e-06
# Epoch 31/200
# 52/52 [==============================] - 21s 404ms/step - loss: 0.9593 - accuracy: 0.5371 - val_loss: 0.9744 - val_accuracy: 0.5000 - lr: 3.0000e-06
# Epoch 32/200
# 52/52 [==============================] - 21s 403ms/step - loss: 0.9541 - accuracy: 0.5323 - val_loss: 0.9702 - val_accuracy: 0.5018 - lr: 3.0000e-06
# Epoch 33/200
# 52/52 [==============================] - 21s 405ms/step - loss: 0.9486 - accuracy: 0.5318 - val_loss: 0.9669 - val_accuracy: 0.5036 - lr: 3.0000e-06
# Epoch 34/200
# 52/52 [==============================] - 21s 407ms/step - loss: 0.9437 - accuracy: 0.5377 - val_loss: 0.9638 - val_accuracy: 0.5053 - lr: 3.0000e-06
# Epoch 35/200
# 52/52 [==============================] - 21s 406ms/step - loss: 0.9357 - accuracy: 0.5490 - val_loss: 0.9611 - val_accuracy: 0.5125 - lr: 3.0000e-06
# Epoch 36/200
# 52/52 [==============================] - 21s 407ms/step - loss: 0.9362 - accuracy: 0.5359 - val_loss: 0.9576 - val_accuracy: 0.5107 - lr: 3.0000e-06
# Epoch 37/200
# 52/52 [==============================] - 21s 407ms/step - loss: 0.9302 - accuracy: 0.5395 - val_loss: 0.9543 - val_accuracy: 0.5107 - lr: 3.0000e-06
# Epoch 38/200
# 52/52 [==============================] - 21s 404ms/step - loss: 0.9251 - accuracy: 0.5436 - val_loss: 0.9519 - val_accuracy: 0.5125 - lr: 3.0000e-06
# Epoch 39/200
# 52/52 [==============================] - 21s 405ms/step - loss: 0.9206 - accuracy: 0.5513 - val_loss: 0.9486 - val_accuracy: 0.5142 - lr: 3.0000e-06
# Epoch 40/200
# 52/52 [==============================] - 21s 406ms/step - loss: 0.9154 - accuracy: 0.5513 - val_loss: 0.9454 - val_accuracy: 0.5178 - lr: 3.0000e-06
# Epoch 41/200
# 52/52 [==============================] - 21s 404ms/step - loss: 0.9080 - accuracy: 0.5561 - val_loss: 0.9421 - val_accuracy: 0.5196 - lr: 3.0000e-06
# Epoch 42/200
# 52/52 [==============================] - 22s 409ms/step - loss: 0.9007 - accuracy: 0.5573 - val_loss: 0.9388 - val_accuracy: 0.5231 - lr: 3.0000e-06
# Epoch 43/200
# 52/52 [==============================] - 21s 407ms/step - loss: 0.9001 - accuracy: 0.5543 - val_loss: 0.9354 - val_accuracy: 0.5267 - lr: 3.0000e-06
# Epoch 44/200
# 52/52 [==============================] - 21s 405ms/step - loss: 0.8937 - accuracy: 0.5602 - val_loss: 0.9322 - val_accuracy: 0.5302 - lr: 3.0000e-06
# Epoch 45/200
# 52/52 [==============================] - 21s 406ms/step - loss: 0.8906 - accuracy: 0.5620 - val_loss: 0.9290 - val_accuracy: 0.5320 - lr: 3.0000e-06
# Epoch 46/200
# 52/52 [==============================] - 21s 405ms/step - loss: 0.8840 - accuracy: 0.5674 - val_loss: 0.9254 - val_accuracy: 0.5356 - lr: 3.0000e-06
# Epoch 47/200
# 52/52 [==============================] - 21s 408ms/step - loss: 0.8805 - accuracy: 0.5614 - val_loss: 0.9220 - val_accuracy: 0.5374 - lr: 3.0000e-06
# Epoch 48/200
# 52/52 [==============================] - 23s 430ms/step - loss: 0.8702 - accuracy: 0.5810 - val_loss: 0.9186 - val_accuracy: 0.5409 - lr: 3.0000e-06
# Epoch 49/200
# 52/52 [==============================] - 21s 408ms/step - loss: 0.8684 - accuracy: 0.5745 - val_loss: 0.9157 - val_accuracy: 0.5463 - lr: 3.0000e-06
# Epoch 50/200
# 52/52 [==============================] - 21s 404ms/step - loss: 0.8618 - accuracy: 0.5751 - val_loss: 0.9118 - val_accuracy: 0.5463 - lr: 3.0000e-06
# Epoch 51/200
# 52/52 [==============================] - 21s 408ms/step - loss: 0.8618 - accuracy: 0.5733 - val_loss: 0.9084 - val_accuracy: 0.5445 - lr: 3.0000e-06
# Epoch 52/200
# 52/52 [==============================] - 21s 407ms/step - loss: 0.8538 - accuracy: 0.5828 - val_loss: 0.9054 - val_accuracy: 0.5409 - lr: 3.0000e-06
# Epoch 53/200
# 52/52 [==============================] - 21s 406ms/step - loss: 0.8448 - accuracy: 0.5804 - val_loss: 0.9012 - val_accuracy: 0.5409 - lr: 3.0000e-06
# Epoch 54/200
# 52/52 [==============================] - 21s 402ms/step - loss: 0.8434 - accuracy: 0.5893 - val_loss: 0.8979 - val_accuracy: 0.5427 - lr: 3.0000e-06
# Epoch 55/200
# 52/52 [==============================] - 23s 429ms/step - loss: 0.8405 - accuracy: 0.5769 - val_loss: 0.8946 - val_accuracy: 0.5480 - lr: 3.0000e-06
# Epoch 56/200
# 52/52 [==============================] - 21s 406ms/step - loss: 0.8315 - accuracy: 0.5988 - val_loss: 0.8909 - val_accuracy: 0.5427 - lr: 3.0000e-06
# Epoch 57/200
# 52/52 [==============================] - 21s 405ms/step - loss: 0.8243 - accuracy: 0.5929 - val_loss: 0.8869 - val_accuracy: 0.5445 - lr: 3.0000e-06
# Epoch 58/200
# 52/52 [==============================] - 21s 407ms/step - loss: 0.8223 - accuracy: 0.5899 - val_loss: 0.8826 - val_accuracy: 0.5480 - lr: 3.0000e-06
# Epoch 59/200
# 52/52 [==============================] - 21s 409ms/step - loss: 0.8194 - accuracy: 0.5834 - val_loss: 0.8785 - val_accuracy: 0.5480 - lr: 3.0000e-06
# Epoch 60/200
# 52/52 [==============================] - 21s 406ms/step - loss: 0.8112 - accuracy: 0.6065 - val_loss: 0.8725 - val_accuracy: 0.5587 - lr: 3.0000e-06
# Epoch 61/200
# 52/52 [==============================] - 21s 405ms/step - loss: 0.8000 - accuracy: 0.6125 - val_loss: 0.8680 - val_accuracy: 0.5587 - lr: 3.0000e-06
# Epoch 62/200
# 52/52 [==============================] - 23s 430ms/step - loss: 0.7970 - accuracy: 0.6083 - val_loss: 0.8640 - val_accuracy: 0.5605 - lr: 3.0000e-06
# Epoch 63/200
# 52/52 [==============================] - 21s 404ms/step - loss: 0.7915 - accuracy: 0.6030 - val_loss: 0.8598 - val_accuracy: 0.5694 - lr: 3.0000e-06
# Epoch 64/200
# 52/52 [==============================] - 21s 407ms/step - loss: 0.7817 - accuracy: 0.6172 - val_loss: 0.8557 - val_accuracy: 0.5765 - lr: 3.0000e-06
# Epoch 65/200
# 52/52 [==============================] - 21s 406ms/step - loss: 0.7747 - accuracy: 0.6303 - val_loss: 0.8520 - val_accuracy: 0.5836 - lr: 3.0000e-06
# Epoch 66/200
# 52/52 [==============================] - 21s 405ms/step - loss: 0.7719 - accuracy: 0.6220 - val_loss: 0.8486 - val_accuracy: 0.5872 - lr: 3.0000e-06
# Epoch 67/200
# 52/52 [==============================] - 21s 409ms/step - loss: 0.7649 - accuracy: 0.6297 - val_loss: 0.8444 - val_accuracy: 0.5890 - lr: 3.0000e-06
# Epoch 68/200
# 52/52 [==============================] - 21s 405ms/step - loss: 0.7594 - accuracy: 0.6374 - val_loss: 0.8407 - val_accuracy: 0.6032 - lr: 3.0000e-06
# Epoch 69/200
# 52/52 [==============================] - 21s 403ms/step - loss: 0.7551 - accuracy: 0.6582 - val_loss: 0.8368 - val_accuracy: 0.6139 - lr: 3.0000e-06
# Epoch 70/200
# 52/52 [==============================] - 21s 408ms/step - loss: 0.7444 - accuracy: 0.6694 - val_loss: 0.8335 - val_accuracy: 0.6281 - lr: 3.0000e-06
# Epoch 71/200
# 52/52 [==============================] - 21s 407ms/step - loss: 0.7425 - accuracy: 0.6908 - val_loss: 0.8296 - val_accuracy: 0.6406 - lr: 3.0000e-06
# Epoch 72/200
# 52/52 [==============================] - 21s 405ms/step - loss: 0.7387 - accuracy: 0.6920 - val_loss: 0.8269 - val_accuracy: 0.6530 - lr: 3.0000e-06
# Epoch 73/200
# 52/52 [==============================] - 21s 407ms/step - loss: 0.7331 - accuracy: 0.7050 - val_loss: 0.8235 - val_accuracy: 0.6584 - lr: 3.0000e-06
# Epoch 74/200
# 52/52 [==============================] - 21s 407ms/step - loss: 0.7284 - accuracy: 0.7175 - val_loss: 0.8204 - val_accuracy: 0.6673 - lr: 3.0000e-06
# Epoch 75/200
# 52/52 [==============================] - 21s 408ms/step - loss: 0.7242 - accuracy: 0.7312 - val_loss: 0.8177 - val_accuracy: 0.6779 - lr: 3.0000e-06
# Epoch 76/200
# 52/52 [==============================] - 22s 409ms/step - loss: 0.7180 - accuracy: 0.7335 - val_loss: 0.8143 - val_accuracy: 0.6833 - lr: 3.0000e-06
# Epoch 77/200
# 52/52 [==============================] - 22s 410ms/step - loss: 0.7145 - accuracy: 0.7430 - val_loss: 0.8123 - val_accuracy: 0.6922 - lr: 3.0000e-06
# Epoch 78/200
# 52/52 [==============================] - 21s 406ms/step - loss: 0.7160 - accuracy: 0.7424 - val_loss: 0.8101 - val_accuracy: 0.6957 - lr: 3.0000e-06
# Epoch 79/200
# 52/52 [==============================] - 21s 406ms/step - loss: 0.7053 - accuracy: 0.7501 - val_loss: 0.8074 - val_accuracy: 0.6993 - lr: 3.0000e-06
# Epoch 80/200
# 52/52 [==============================] - 21s 403ms/step - loss: 0.7096 - accuracy: 0.7466 - val_loss: 0.8049 - val_accuracy: 0.7082 - lr: 3.0000e-06
# Epoch 81/200
# 52/52 [==============================] - 21s 404ms/step - loss: 0.7031 - accuracy: 0.7549 - val_loss: 0.8026 - val_accuracy: 0.7206 - lr: 3.0000e-06
# Epoch 82/200
# 52/52 [==============================] - 21s 405ms/step - loss: 0.6904 - accuracy: 0.7608 - val_loss: 0.7997 - val_accuracy: 0.7242 - lr: 3.0000e-06
# Epoch 83/200
# 52/52 [==============================] - 21s 404ms/step - loss: 0.6954 - accuracy: 0.7608 - val_loss: 0.7973 - val_accuracy: 0.7242 - lr: 3.0000e-06
# Epoch 84/200
# 52/52 [==============================] - 21s 409ms/step - loss: 0.6808 - accuracy: 0.7751 - val_loss: 0.7943 - val_accuracy: 0.7242 - lr: 3.0000e-06
# Epoch 85/200
# 52/52 [==============================] - 21s 409ms/step - loss: 0.6864 - accuracy: 0.7685 - val_loss: 0.7923 - val_accuracy: 0.7295 - lr: 3.0000e-06
# Epoch 86/200
# 52/52 [==============================] - 21s 407ms/step - loss: 0.6813 - accuracy: 0.7680 - val_loss: 0.7903 - val_accuracy: 0.7295 - lr: 3.0000e-06
# Epoch 87/200
# 52/52 [==============================] - 21s 404ms/step - loss: 0.6743 - accuracy: 0.7828 - val_loss: 0.7867 - val_accuracy: 0.7313 - lr: 3.0000e-06
# Epoch 88/200
# 52/52 [==============================] - 21s 403ms/step - loss: 0.6686 - accuracy: 0.7804 - val_loss: 0.7847 - val_accuracy: 0.7331 - lr: 3.0000e-06
# Epoch 89/200
# 52/52 [==============================] - 21s 407ms/step - loss: 0.6644 - accuracy: 0.7804 - val_loss: 0.7825 - val_accuracy: 0.7349 - lr: 3.0000e-06
# Epoch 90/200
# 52/52 [==============================] - 21s 407ms/step - loss: 0.6575 - accuracy: 0.7798 - val_loss: 0.7811 - val_accuracy: 0.7367 - lr: 3.0000e-06
# Epoch 91/200
# 52/52 [==============================] - 23s 428ms/step - loss: 0.6546 - accuracy: 0.7852 - val_loss: 0.7791 - val_accuracy: 0.7402 - lr: 3.0000e-06
# Epoch 92/200
# 52/52 [==============================] - 21s 405ms/step - loss: 0.6581 - accuracy: 0.7911 - val_loss: 0.7770 - val_accuracy: 0.7402 - lr: 3.0000e-06
# Epoch 93/200
# 52/52 [==============================] - 21s 409ms/step - loss: 0.6510 - accuracy: 0.7941 - val_loss: 0.7746 - val_accuracy: 0.7402 - lr: 3.0000e-06
# Epoch 94/200
# 52/52 [==============================] - 21s 403ms/step - loss: 0.6474 - accuracy: 0.7941 - val_loss: 0.7737 - val_accuracy: 0.7438 - lr: 3.0000e-06
# Epoch 95/200
# 52/52 [==============================] - 21s 404ms/step - loss: 0.6451 - accuracy: 0.7899 - val_loss: 0.7703 - val_accuracy: 0.7420 - lr: 3.0000e-06
# Epoch 96/200
# 52/52 [==============================] - 21s 407ms/step - loss: 0.6342 - accuracy: 0.7976 - val_loss: 0.7688 - val_accuracy: 0.7384 - lr: 3.0000e-06
# Epoch 97/200
# 52/52 [==============================] - 21s 405ms/step - loss: 0.6279 - accuracy: 0.8059 - val_loss: 0.7672 - val_accuracy: 0.7438 - lr: 3.0000e-06
# Epoch 98/200
# 52/52 [==============================] - 21s 407ms/step - loss: 0.6308 - accuracy: 0.7994 - val_loss: 0.7641 - val_accuracy: 0.7438 - lr: 3.0000e-06
# Epoch 99/200
# 52/52 [==============================] - 21s 408ms/step - loss: 0.6276 - accuracy: 0.8077 - val_loss: 0.7630 - val_accuracy: 0.7456 - lr: 3.0000e-06
# Epoch 100/200
# 52/52 [==============================] - 23s 431ms/step - loss: 0.6298 - accuracy: 0.7869 - val_loss: 0.7615 - val_accuracy: 0.7491 - lr: 3.0000e-06
# Epoch 101/200
# 52/52 [==============================] - 21s 406ms/step - loss: 0.6152 - accuracy: 0.8148 - val_loss: 0.7600 - val_accuracy: 0.7527 - lr: 3.0000e-06
# Epoch 102/200
# 52/52 [==============================] - 21s 405ms/step - loss: 0.6216 - accuracy: 0.8042 - val_loss: 0.7602 - val_accuracy: 0.7562 - lr: 3.0000e-06
# Epoch 103/200
# 52/52 [==============================] - 21s 405ms/step - loss: 0.6168 - accuracy: 0.8036 - val_loss: 0.7564 - val_accuracy: 0.7580 - lr: 3.0000e-06
# Epoch 104/200
# 52/52 [==============================] - 21s 405ms/step - loss: 0.6112 - accuracy: 0.8095 - val_loss: 0.7555 - val_accuracy: 0.7580 - lr: 3.0000e-06
# Epoch 105/200
# 52/52 [==============================] - 21s 408ms/step - loss: 0.6151 - accuracy: 0.8101 - val_loss: 0.7533 - val_accuracy: 0.7580 - lr: 3.0000e-06
# Epoch 106/200
# 52/52 [==============================] - 21s 405ms/step - loss: 0.6010 - accuracy: 0.8172 - val_loss: 0.7528 - val_accuracy: 0.7562 - lr: 3.0000e-06
# Epoch 107/200
# 52/52 [==============================] - 21s 408ms/step - loss: 0.6066 - accuracy: 0.8065 - val_loss: 0.7513 - val_accuracy: 0.7562 - lr: 3.0000e-06
# Epoch 108/200
# 52/52 [==============================] - 21s 409ms/step - loss: 0.5991 - accuracy: 0.8059 - val_loss: 0.7491 - val_accuracy: 0.7598 - lr: 3.0000e-06
# Epoch 109/200
# 52/52 [==============================] - 21s 406ms/step - loss: 0.5908 - accuracy: 0.8184 - val_loss: 0.7470 - val_accuracy: 0.7580 - lr: 3.0000e-06
# Epoch 110/200
# 52/52 [==============================] - 21s 407ms/step - loss: 0.5899 - accuracy: 0.8059 - val_loss: 0.7457 - val_accuracy: 0.7598 - lr: 3.0000e-06
# Epoch 111/200
# 52/52 [==============================] - 21s 407ms/step - loss: 0.5867 - accuracy: 0.8148 - val_loss: 0.7453 - val_accuracy: 0.7580 - lr: 3.0000e-06
# Epoch 112/200
# 52/52 [==============================] - 21s 406ms/step - loss: 0.5799 - accuracy: 0.8196 - val_loss: 0.7436 - val_accuracy: 0.7562 - lr: 3.0000e-06
# Epoch 113/200
# 52/52 [==============================] - 21s 405ms/step - loss: 0.5816 - accuracy: 0.8136 - val_loss: 0.7428 - val_accuracy: 0.7544 - lr: 3.0000e-06
# Epoch 114/200
# 52/52 [==============================] - 21s 407ms/step - loss: 0.5810 - accuracy: 0.8214 - val_loss: 0.7409 - val_accuracy: 0.7580 - lr: 3.0000e-06
# Epoch 115/200
# 52/52 [==============================] - 21s 408ms/step - loss: 0.5859 - accuracy: 0.8136 - val_loss: 0.7398 - val_accuracy: 0.7580 - lr: 3.0000e-06
# Epoch 116/200
# 52/52 [==============================] - 21s 406ms/step - loss: 0.5717 - accuracy: 0.8184 - val_loss: 0.7380 - val_accuracy: 0.7616 - lr: 3.0000e-06
# Epoch 117/200
# 52/52 [==============================] - 21s 407ms/step - loss: 0.5668 - accuracy: 0.8220 - val_loss: 0.7355 - val_accuracy: 0.7616 - lr: 3.0000e-06
# Epoch 118/200
# 52/52 [==============================] - 21s 408ms/step - loss: 0.5650 - accuracy: 0.8214 - val_loss: 0.7343 - val_accuracy: 0.7598 - lr: 3.0000e-06
# Epoch 119/200
# 52/52 [==============================] - 21s 406ms/step - loss: 0.5692 - accuracy: 0.8178 - val_loss: 0.7337 - val_accuracy: 0.7651 - lr: 3.0000e-06
# Epoch 120/200
# 52/52 [==============================] - 21s 406ms/step - loss: 0.5587 - accuracy: 0.8237 - val_loss: 0.7318 - val_accuracy: 0.7651 - lr: 3.0000e-06
# Epoch 121/200
# 52/52 [==============================] - 21s 406ms/step - loss: 0.5614 - accuracy: 0.8291 - val_loss: 0.7310 - val_accuracy: 0.7669 - lr: 3.0000e-06
# Epoch 122/200
# 52/52 [==============================] - 21s 403ms/step - loss: 0.5558 - accuracy: 0.8231 - val_loss: 0.7300 - val_accuracy: 0.7651 - lr: 3.0000e-06
# Epoch 123/200
# 52/52 [==============================] - 21s 406ms/step - loss: 0.5531 - accuracy: 0.8249 - val_loss: 0.7297 - val_accuracy: 0.7669 - lr: 3.0000e-06
# Epoch 124/200
# 52/52 [==============================] - 21s 405ms/step - loss: 0.5533 - accuracy: 0.8237 - val_loss: 0.7286 - val_accuracy: 0.7687 - lr: 3.0000e-06
# Epoch 125/200
# 52/52 [==============================] - 21s 404ms/step - loss: 0.5438 - accuracy: 0.8279 - val_loss: 0.7281 - val_accuracy: 0.7669 - lr: 3.0000e-06
# Epoch 126/200
# 52/52 [==============================] - 23s 432ms/step - loss: 0.5475 - accuracy: 0.8297 - val_loss: 0.7269 - val_accuracy: 0.7687 - lr: 3.0000e-06
# Epoch 127/200
# 52/52 [==============================] - 21s 404ms/step - loss: 0.5388 - accuracy: 0.8320 - val_loss: 0.7254 - val_accuracy: 0.7705 - lr: 3.0000e-06
# Epoch 128/200
# 52/52 [==============================] - 21s 405ms/step - loss: 0.5363 - accuracy: 0.8362 - val_loss: 0.7244 - val_accuracy: 0.7669 - lr: 3.0000e-06
# Epoch 129/200
# 52/52 [==============================] - 21s 405ms/step - loss: 0.5386 - accuracy: 0.8356 - val_loss: 0.7222 - val_accuracy: 0.7705 - lr: 3.0000e-06
# Epoch 130/200
# 52/52 [==============================] - 21s 405ms/step - loss: 0.5440 - accuracy: 0.8190 - val_loss: 0.7216 - val_accuracy: 0.7758 - lr: 3.0000e-06
# Epoch 131/200
# 52/52 [==============================] - 21s 406ms/step - loss: 0.5314 - accuracy: 0.8350 - val_loss: 0.7209 - val_accuracy: 0.7740 - lr: 3.0000e-06
# Epoch 132/200
# 52/52 [==============================] - 23s 431ms/step - loss: 0.5371 - accuracy: 0.8320 - val_loss: 0.7187 - val_accuracy: 0.7758 - lr: 3.0000e-06
# Epoch 133/200
# 52/52 [==============================] - 21s 406ms/step - loss: 0.5227 - accuracy: 0.8374 - val_loss: 0.7189 - val_accuracy: 0.7740 - lr: 3.0000e-06
# Epoch 134/200
# 52/52 [==============================] - 21s 407ms/step - loss: 0.5225 - accuracy: 0.8332 - val_loss: 0.7164 - val_accuracy: 0.7740 - lr: 3.0000e-06
# Epoch 135/200
# 52/52 [==============================] - 21s 405ms/step - loss: 0.5171 - accuracy: 0.8362 - val_loss: 0.7125 - val_accuracy: 0.7740 - lr: 3.0000e-06
# Epoch 136/200
# 52/52 [==============================] - 21s 401ms/step - loss: 0.5088 - accuracy: 0.8374 - val_loss: 0.7061 - val_accuracy: 0.7705 - lr: 3.0000e-06
# Epoch 137/200
# 52/52 [==============================] - 21s 406ms/step - loss: 0.4986 - accuracy: 0.8368 - val_loss: 0.6935 - val_accuracy: 0.7705 - lr: 3.0000e-06
# Epoch 138/200
# 52/52 [==============================] - 22s 427ms/step - loss: 0.4956 - accuracy: 0.8332 - val_loss: 0.6832 - val_accuracy: 0.7740 - lr: 3.0000e-06
# Epoch 139/200
# 52/52 [==============================] - 21s 406ms/step - loss: 0.4839 - accuracy: 0.8320 - val_loss: 0.6778 - val_accuracy: 0.7705 - lr: 3.0000e-06
# Epoch 140/200
# 52/52 [==============================] - 21s 407ms/step - loss: 0.4704 - accuracy: 0.8421 - val_loss: 0.6696 - val_accuracy: 0.7705 - lr: 3.0000e-06
# Epoch 141/200
# 52/52 [==============================] - 21s 405ms/step - loss: 0.4684 - accuracy: 0.8427 - val_loss: 0.6653 - val_accuracy: 0.7705 - lr: 3.0000e-06
# Epoch 142/200
# 52/52 [==============================] - 21s 407ms/step - loss: 0.4658 - accuracy: 0.8392 - val_loss: 0.6633 - val_accuracy: 0.7722 - lr: 3.0000e-06
# Epoch 143/200
# 52/52 [==============================] - 21s 401ms/step - loss: 0.4677 - accuracy: 0.8398 - val_loss: 0.6592 - val_accuracy: 0.7740 - lr: 3.0000e-06
# Epoch 144/200
# 52/52 [==============================] - 21s 407ms/step - loss: 0.4544 - accuracy: 0.8315 - val_loss: 0.6591 - val_accuracy: 0.7758 - lr: 3.0000e-06
# Epoch 145/200
# 52/52 [==============================] - 21s 407ms/step - loss: 0.4522 - accuracy: 0.8457 - val_loss: 0.6574 - val_accuracy: 0.7740 - lr: 3.0000e-06
# Epoch 146/200
# 52/52 [==============================] - 21s 405ms/step - loss: 0.4432 - accuracy: 0.8404 - val_loss: 0.6574 - val_accuracy: 0.7705 - lr: 3.0000e-06
# Epoch 147/200
# 52/52 [==============================] - 21s 407ms/step - loss: 0.4516 - accuracy: 0.8326 - val_loss: 0.6562 - val_accuracy: 0.7740 - lr: 3.0000e-06
# Epoch 148/200
# 52/52 [==============================] - 23s 429ms/step - loss: 0.4560 - accuracy: 0.8344 - val_loss: 0.6512 - val_accuracy: 0.7705 - lr: 3.0000e-06
# Epoch 149/200
# 52/52 [==============================] - 21s 406ms/step - loss: 0.4363 - accuracy: 0.8504 - val_loss: 0.6525 - val_accuracy: 0.7705 - lr: 3.0000e-06
# Epoch 150/200
# 52/52 [==============================] - 21s 409ms/step - loss: 0.4353 - accuracy: 0.8457 - val_loss: 0.6504 - val_accuracy: 0.7740 - lr: 3.0000e-06
# Epoch 151/200
# 52/52 [==============================] - 23s 429ms/step - loss: 0.4321 - accuracy: 0.8427 - val_loss: 0.6488 - val_accuracy: 0.7776 - lr: 3.0000e-06
# Epoch 152/200
# 52/52 [==============================] - 23s 431ms/step - loss: 0.4387 - accuracy: 0.8398 - val_loss: 0.6446 - val_accuracy: 0.7794 - lr: 3.0000e-06
# Epoch 153/200
# 52/52 [==============================] - 21s 406ms/step - loss: 0.4318 - accuracy: 0.8487 - val_loss: 0.6425 - val_accuracy: 0.7740 - lr: 3.0000e-06
# Epoch 154/200
# 52/52 [==============================] - 21s 409ms/step - loss: 0.4315 - accuracy: 0.8409 - val_loss: 0.6389 - val_accuracy: 0.7776 - lr: 3.0000e-06
# Epoch 155/200
# 52/52 [==============================] - 21s 400ms/step - loss: 0.4174 - accuracy: 0.8516 - val_loss: 0.6419 - val_accuracy: 0.7794 - lr: 3.0000e-06
# Epoch 156/200
# 52/52 [==============================] - 21s 402ms/step - loss: 0.4211 - accuracy: 0.8493 - val_loss: 0.6425 - val_accuracy: 0.7758 - lr: 3.0000e-06
# Epoch 157/200
# 52/52 [==============================] - 21s 407ms/step - loss: 0.4244 - accuracy: 0.8481 - val_loss: 0.6423 - val_accuracy: 0.7811 - lr: 3.0000e-06
# Epoch 158/200
# 52/52 [==============================] - 22s 428ms/step - loss: 0.4227 - accuracy: 0.8463 - val_loss: 0.6434 - val_accuracy: 0.7794 - lr: 3.0000e-06
# Epoch 159/200
# 52/52 [==============================] - 21s 405ms/step - loss: 0.4037 - accuracy: 0.8611 - val_loss: 0.6431 - val_accuracy: 0.7811 - lr: 3.0000e-06
# Epoch 160/200
# 52/52 [==============================] - 21s 405ms/step - loss: 0.4118 - accuracy: 0.8487 - val_loss: 0.6391 - val_accuracy: 0.7829 - lr: 3.0000e-06
# Epoch 161/200
# 52/52 [==============================] - 21s 402ms/step - loss: 0.4134 - accuracy: 0.8570 - val_loss: 0.6392 - val_accuracy: 0.7865 - lr: 3.0000e-06
# Epoch 162/200
# 52/52 [==============================] - 21s 404ms/step - loss: 0.4084 - accuracy: 0.8463 - val_loss: 0.6381 - val_accuracy: 0.7847 - lr: 3.0000e-06
# Epoch 163/200
# 52/52 [==============================] - 21s 403ms/step - loss: 0.4071 - accuracy: 0.8516 - val_loss: 0.6374 - val_accuracy: 0.7865 - lr: 3.0000e-06
# Epoch 164/200
# 52/52 [==============================] - 21s 404ms/step - loss: 0.4017 - accuracy: 0.8564 - val_loss: 0.6377 - val_accuracy: 0.7918 - lr: 3.0000e-06
# Epoch 165/200
# 52/52 [==============================] - 21s 406ms/step - loss: 0.3956 - accuracy: 0.8570 - val_loss: 0.6364 - val_accuracy: 0.7918 - lr: 3.0000e-06
# Epoch 166/200
# 52/52 [==============================] - 21s 404ms/step - loss: 0.4055 - accuracy: 0.8510 - val_loss: 0.6366 - val_accuracy: 0.7918 - lr: 3.0000e-06
# Epoch 167/200
# 52/52 [==============================] - 21s 397ms/step - loss: 0.3897 - accuracy: 0.8623 - val_loss: 0.6367 - val_accuracy: 0.7918 - lr: 3.0000e-06
# Epoch 168/200
# 52/52 [==============================] - 21s 404ms/step - loss: 0.4024 - accuracy: 0.8540 - val_loss: 0.6379 - val_accuracy: 0.7883 - lr: 3.0000e-06
# Epoch 169/200
# 52/52 [==============================] - 21s 402ms/step - loss: 0.3876 - accuracy: 0.8576 - val_loss: 0.6366 - val_accuracy: 0.7865 - lr: 3.0000e-06
# Epoch 170/200
# 52/52 [==============================] - 21s 408ms/step - loss: 0.3939 - accuracy: 0.8552 - val_loss: 0.6361 - val_accuracy: 0.7883 - lr: 3.0000e-06
# Epoch 171/200
# 52/52 [==============================] - 22s 425ms/step - loss: 0.3901 - accuracy: 0.8564 - val_loss: 0.6347 - val_accuracy: 0.7883 - lr: 3.0000e-06
# Epoch 172/200
# 52/52 [==============================] - 21s 406ms/step - loss: 0.3930 - accuracy: 0.8564 - val_loss: 0.6350 - val_accuracy: 0.7900 - lr: 3.0000e-06
# Epoch 173/200
# 52/52 [==============================] - 21s 407ms/step - loss: 0.3740 - accuracy: 0.8718 - val_loss: 0.6343 - val_accuracy: 0.7883 - lr: 3.0000e-06
# Epoch 174/200
# 52/52 [==============================] - 21s 407ms/step - loss: 0.3812 - accuracy: 0.8629 - val_loss: 0.6344 - val_accuracy: 0.7936 - lr: 3.0000e-06
# Epoch 175/200
# 52/52 [==============================] - 21s 405ms/step - loss: 0.3817 - accuracy: 0.8576 - val_loss: 0.6366 - val_accuracy: 0.7918 - lr: 3.0000e-06
# Epoch 176/200
# 52/52 [==============================] - 22s 428ms/step - loss: 0.3758 - accuracy: 0.8582 - val_loss: 0.6340 - val_accuracy: 0.7936 - lr: 3.0000e-06
# Epoch 177/200
# 52/52 [==============================] - 21s 402ms/step - loss: 0.3778 - accuracy: 0.8576 - val_loss: 0.6354 - val_accuracy: 0.7883 - lr: 3.0000e-06
# Epoch 178/200
# 52/52 [==============================] - 21s 405ms/step - loss: 0.3710 - accuracy: 0.8635 - val_loss: 0.6358 - val_accuracy: 0.7883 - lr: 3.0000e-06
# Epoch 179/200
# 52/52 [==============================] - 21s 405ms/step - loss: 0.3732 - accuracy: 0.8641 - val_loss: 0.6386 - val_accuracy: 0.7865 - lr: 3.0000e-06
# Epoch 180/200
# 52/52 [==============================] - 21s 404ms/step - loss: 0.3734 - accuracy: 0.8635 - val_loss: 0.6390 - val_accuracy: 0.7883 - lr: 3.0000e-06
# Epoch 181/200
# 52/52 [==============================] - 21s 403ms/step - loss: 0.3736 - accuracy: 0.8623 - val_loss: 0.6380 - val_accuracy: 0.7900 - lr: 3.0000e-06
# Epoch 182/200
# 52/52 [==============================] - 21s 406ms/step - loss: 0.3685 - accuracy: 0.8665 - val_loss: 0.6406 - val_accuracy: 0.7883 - lr: 3.0000e-06
# Epoch 183/200
# 52/52 [==============================] - 22s 427ms/step - loss: 0.3640 - accuracy: 0.8677 - val_loss: 0.6419 - val_accuracy: 0.7865 - lr: 3.0000e-06
# Epoch 184/200
# 52/52 [==============================] - 21s 403ms/step - loss: 0.3616 - accuracy: 0.8724 - val_loss: 0.6399 - val_accuracy: 0.7883 - lr: 3.0000e-06
# Epoch 185/200
# 52/52 [==============================] - 21s 404ms/step - loss: 0.3748 - accuracy: 0.8605 - val_loss: 0.6390 - val_accuracy: 0.7900 - lr: 3.0000e-06
# Epoch 186/200
# 52/52 [==============================] - 21s 404ms/step - loss: 0.3621 - accuracy: 0.8671 - val_loss: 0.6381 - val_accuracy: 0.7900 - lr: 3.0000e-06
# Epoch 187/200
# 52/52 [==============================] - 21s 406ms/step - loss: 0.3682 - accuracy: 0.8617 - val_loss: 0.6388 - val_accuracy: 0.7918 - lr: 3.0000e-06
# Epoch 188/200
# 52/52 [==============================] - 21s 405ms/step - loss: 0.3564 - accuracy: 0.8605 - val_loss: 0.6391 - val_accuracy: 0.7936 - lr: 3.0000e-06
# Epoch 189/200
# 52/52 [==============================] - 21s 406ms/step - loss: 0.3582 - accuracy: 0.8641 - val_loss: 0.6425 - val_accuracy: 0.7883 - lr: 3.0000e-06
# Epoch 190/200
# 52/52 [==============================] - 21s 405ms/step - loss: 0.3671 - accuracy: 0.8641 - val_loss: 0.6401 - val_accuracy: 0.7918 - lr: 3.0000e-06
# Epoch 191/200
# 52/52 [==============================] - 21s 403ms/step - loss: 0.3503 - accuracy: 0.8700 - val_loss: 0.6409 - val_accuracy: 0.7918 - lr: 3.0000e-06
# Epoch 192/200
# 52/52 [==============================] - 21s 407ms/step - loss: 0.3566 - accuracy: 0.8635 - val_loss: 0.6400 - val_accuracy: 0.7936 - lr: 3.0000e-06
# Epoch 193/200
# 52/52 [==============================] - 23s 429ms/step - loss: 0.3578 - accuracy: 0.8688 - val_loss: 0.6387 - val_accuracy: 0.7918 - lr: 3.0000e-06
# Epoch 194/200
# 52/52 [==============================] - 21s 405ms/step - loss: 0.3672 - accuracy: 0.8641 - val_loss: 0.6413 - val_accuracy: 0.7918 - lr: 3.0000e-06
# Epoch 195/200
# 52/52 [==============================] - 21s 407ms/step - loss: 0.3556 - accuracy: 0.8653 - val_loss: 0.6428 - val_accuracy: 0.7918 - lr: 3.0000e-06
# Epoch 196/200
# 52/52 [==============================] - 21s 401ms/step - loss: 0.3477 - accuracy: 0.8700 - val_loss: 0.6448 - val_accuracy: 0.7847 - lr: 3.0000e-06
# Epoch 197/200
# 52/52 [==============================] - 21s 403ms/step - loss: 0.3559 - accuracy: 0.8682 - val_loss: 0.6470 - val_accuracy: 0.7865 - lr: 3.0000e-06
# Epoch 198/200
# 52/52 [==============================] - 21s 407ms/step - loss: 0.3552 - accuracy: 0.8700 - val_loss: 0.6470 - val_accuracy: 0.7883 - lr: 3.0000e-06
# Epoch 199/200
# 52/52 [==============================] - 21s 407ms/step - loss: 0.3491 - accuracy: 0.8712 - val_loss: 0.6447 - val_accuracy: 0.7900 - lr: 3.0000e-06
# Epoch 200/200
# 52/52 [==============================] - 21s 404ms/step - loss: 0.3452 - accuracy: 0.8724 - val_loss: 0.6456 - val_accuracy: 0.7883 - lr: 3.0000e-06

# %% [markdown]
# save model weight

# %%
model.save_weights('ocular_v7.h5')
model.save('ocular_model_v7.h5')
